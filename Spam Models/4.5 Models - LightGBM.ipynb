# %%
import pandas as pd
import numpy as np
import time

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint as sp_randint
from scipy.stats import uniform as sp_uniform

import lightgbm as lgbm
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, accuracy_score, f1_score

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Reading in data sources

# %% [markdown]
# ###**Spam** data sets

# %%
## Full features
X_train_full = pd.read_pickle('/content/gdrive/My Drive/BT4222/Codes/Cleaned Input Data/Full Text SPAM/X_train_fSP.pkl')
X_test_full = pd.read_pickle('/content/gdrive/My Drive/BT4222/Codes/Cleaned Input Data/Full Text SPAM/X_test_fSP.pkl')

## Vanilla features
X_train_v = X_train_full.drop(['text', 'cleaned_text', 'cleaned_text_full'], axis=1)
X_test_v = X_test_full.drop(['text', 'cleaned_text', 'cleaned_text_full'], axis=1)
scaler = MinMaxScaler()
X_train_scaled = pd.DataFrame(scaler.fit_transform(X_train_v), index = X_train_v.index, columns = X_train_v.columns)
X_test_scaled = pd.DataFrame(scaler.transform(X_test_v), index = X_test_v.index, columns = X_test_v.columns)

## target label
y_train = pd.read_pickle('/content/gdrive/My Drive/BT4222/Codes/Cleaned Input Data/Full Text SPAM/y_train_fSP.pkl')
y_test = pd.read_pickle('/content/gdrive/My Drive/BT4222/Codes/Cleaned Input Data/Full Text SPAM/y_test_fSP.pkl')

## TF-IDF with top 15 features
X_train_tfidf = pd.read_pickle('/content/gdrive/My Drive/BT4222/Codes/Cleaned Input Data/TFIDF SPAM/X_train_tfSP.pkl')
X_test_tfidf = pd.read_pickle('/content/gdrive/My Drive/BT4222/Codes/Cleaned Input Data/TFIDF SPAM/X_test_tfSP.pkl')

## TF-IDF GloVe with top 15 features
X_train_tfidf_glove = pd.read_pickle('/content/gdrive/My Drive/BT4222/Codes/Cleaned Input Data/TFIDF Glove SPAM/X_train_tfglSP.pkl')
X_test_tfidf_glove = pd.read_pickle('/content/gdrive/My Drive/BT4222/Codes/Cleaned Input Data/TFIDF Glove SPAM/X_test_tfglSP.pkl')

## TF-IDF FastText (cc) with top 15 features
X_train_tfidf_cc = pd.read_pickle('/content/gdrive/My Drive/BT4222/Codes/Cleaned Input Data/TFIDF CC SPAM/X_train_tfccSP.pkl')
X_test_tfidf_cc = pd.read_pickle('/content/gdrive/My Drive/BT4222/Codes/Cleaned Input Data/TFIDF CC SPAM/X_test_tfccSP.pkl')

## infersent
X_train_infersent = pd.read_pickle('/content/gdrive/My Drive/BT4222/Codes/Cleaned Input Data/InferSent SPAM/X_train_infSP.pkl')
X_test_infersent = pd.read_pickle('/content/gdrive/My Drive/BT4222/Codes/Cleaned Input Data/InferSent SPAM/X_test_infSP.pkl')
y_train_infersent = pd.read_pickle('/content/gdrive/My Drive/BT4222/Codes/Cleaned Input Data/InferSent SPAM/y_train_infSP.pkl')
y_test_infersent = pd.read_pickle('/content/gdrive/My Drive/BT4222/Codes/Cleaned Input Data/InferSent SPAM/y_test_infSP.pkl')

# %% [markdown]
# ##LightGBM

# %% [markdown]
# ###hyperparameter tuning

# %%
def show_results(y_actual, y_pred, y_prob):
  print(classification_report(y_actual, y_pred, digits=3))
  print(confusion_matrix(y_actual, y_pred))
  print("Accuracy: " + str(accuracy_score(y_actual, y_pred)))
  print("AUC_ROC: " + str(roc_auc_score(y_actual, y_prob)))
  print("f1 score: " + str(f1_score(y_actual, y_pred)))
  tn, fp, fn, tp = confusion_matrix(y_actual, y_pred).ravel()
  fpr = fp/(fp+tn)
  print("False Postive Rate: " + str(fpr) + "\n")

# %%
param_test ={'num_leaves': sp_randint(6, 80), 
             'min_data_in_leaf': sp_randint(20, 100), 
             'min_sum_hessian_in_leaf': [1e-5, 1e-3, 1e-2, 1e-1, 1, 1e1, 1e2, 1e3, 1e4],
             'subsample': sp_uniform(loc=0.2, scale=0.8), 
             'feature_fraction': sp_uniform(loc=0.4, scale=0.6),
             'lambda_l1': [0, 1e-1, 1, 2, 5, 7, 10, 50, 100],
             'lambda_l2': [0, 1e-1, 1, 5, 10, 20, 50, 100],
             'boosting_type': ['goss', 'gbdt', 'dart'],
             'max_depth': sp_randint(-1, 20), 
             'bagging_fraction': sp_uniform(loc=0.1, scale=0.6),
             'early_stopping_round': sp_randint(10, 80), 
             'metric': ['auc', 'l1', 'average_precision'],
             'objective' : ['binary']
             }

# %% [markdown]
# ###training best model for scaled Vanilla features

# %%
clf_1 = lgbm.LGBMClassifier(random_state=1, silent=True)
rs_1 = RandomizedSearchCV(estimator = clf_1, 
                        param_distributions = param_test, 
                        refit = True,
                        random_state = 1,
                        n_jobs = -1
                        )

# %%
fit_params={"early_stopping_rounds":30, 
            "eval_metric" : 'auc', 
            "eval_set" : [(X_train_scaled, y_train)],
            'eval_names': ['valid'],
            'categorical_feature': 'auto',
            }
# %time rs_1.fit(X_train_scaled, y_train, **fit_params)
print('Best score reached: {} with params: {} '.format(rs_1.best_score_, rs_1.best_params_))
# Out:
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:123: UserWarning: Found `early_stopping_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [1]	valid's l1: 0.471296	valid's auc: 0.891815
# Training until validation scores don't improve for 34 rounds.
# [2]	valid's l1: 0.45361	valid's auc: 0.912962
# [3]	valid's l1: 0.435139	valid's auc: 0.922822
# [4]	valid's l1: 0.417811	valid's auc: 0.927525
# [5]	valid's l1: 0.401031	valid's auc: 0.929198
# [6]	valid's l1: 0.388025	valid's auc: 0.93139
# [7]	valid's l1: 0.373551	valid's auc: 0.932609
# [8]	valid's l1: 0.360321	valid's auc: 0.933232
# [9]	valid's l1: 0.350048	valid's auc: 0.934732
# [10]	valid's l1: 0.3406	valid's auc: 0.935588
# [11]	valid's l1: 0.331171	valid's auc: 0.935976
# [12]	valid's l1: 0.322409	valid's auc: 0.936047
# [13]	valid's l1: 0.314956	valid's auc: 0.936154
# [14]	valid's l1: 0.307721	valid's auc: 0.936898
# [15]	valid's l1: 0.301158	valid's auc: 0.937028
# [16]	valid's l1: 0.295295	valid's auc: 0.937623
# [17]	valid's l1: 0.289787	valid's auc: 0.937839
# [18]	valid's l1: 0.284993	valid's auc: 0.938474
# [19]	valid's l1: 0.280673	valid's auc: 0.93892
# [20]	valid's l1: 0.276421	valid's auc: 0.939358
# [21]	valid's l1: 0.271563	valid's auc: 0.940071
# [22]	valid's l1: 0.267871	valid's auc: 0.940358
# [23]	valid's l1: 0.263582	valid's auc: 0.940913
# [24]	valid's l1: 0.259674	valid's auc: 0.941361
# [25]	valid's l1: 0.255623	valid's auc: 0.942183
# [26]	valid's l1: 0.251491	valid's auc: 0.942823
# [27]	valid's l1: 0.248432	valid's auc: 0.943257
# [28]	valid's l1: 0.246135	valid's auc: 0.943694
# [29]	valid's l1: 0.243337	valid's auc: 0.943939
# [30]	valid's l1: 0.240397	valid's auc: 0.94469
# [31]	valid's l1: 0.237779	valid's auc: 0.945404
# [32]	valid's l1: 0.235432	valid's auc: 0.945951
# [33]	valid's l1: 0.232719	valid's auc: 0.946507
# [34]	valid's l1: 0.23045	valid's auc: 0.947075
# [35]	valid's l1: 0.228154	valid's auc: 0.947701
# [36]	valid's l1: 0.22624	valid's auc: 0.948114
# [37]	valid's l1: 0.224853	valid's auc: 0.94838
# [38]	valid's l1: 0.223201	valid's auc: 0.9489
# [39]	valid's l1: 0.221779	valid's auc: 0.949358
# [40]	valid's l1: 0.220385	valid's auc: 0.950047
# [41]	valid's l1: 0.218969	valid's auc: 0.950449
# [42]	valid's l1: 0.217503	valid's auc: 0.950707
# [43]	valid's l1: 0.216091	valid's auc: 0.950881
# [44]	valid's l1: 0.214555	valid's auc: 0.951271
# [45]	valid's l1: 0.213183	valid's auc: 0.95167
# [46]	valid's l1: 0.211375	valid's auc: 0.952188
# [47]	valid's l1: 0.210005	valid's auc: 0.952327
# [48]	valid's l1: 0.208823	valid's auc: 0.952714
# [49]	valid's l1: 0.20781	valid's auc: 0.953103
# [50]	valid's l1: 0.206648	valid's auc: 0.953496
# [51]	valid's l1: 0.205604	valid's auc: 0.953793
# [52]	valid's l1: 0.204365	valid's auc: 0.954095
# [53]	valid's l1: 0.203133	valid's auc: 0.954518
# [54]	valid's l1: 0.202514	valid's auc: 0.954912
# [55]	valid's l1: 0.201645	valid's auc: 0.955208
# [56]	valid's l1: 0.200591	valid's auc: 0.955572
# [57]	valid's l1: 0.199777	valid's auc: 0.955911
# [58]	valid's l1: 0.198845	valid's auc: 0.956261
# [59]	valid's l1: 0.197994	valid's auc: 0.956444
# [60]	valid's l1: 0.197167	valid's auc: 0.956878
# [61]	valid's l1: 0.196439	valid's auc: 0.957299
# [62]	valid's l1: 0.195567	valid's auc: 0.957634
# [63]	valid's l1: 0.194469	valid's auc: 0.957811
# [64]	valid's l1: 0.193375	valid's auc: 0.957979
# [65]	valid's l1: 0.192896	valid's auc: 0.958357
# [66]	valid's l1: 0.192128	valid's auc: 0.95865
# [67]	valid's l1: 0.191231	valid's auc: 0.959001
# [68]	valid's l1: 0.190483	valid's auc: 0.959225
# [69]	valid's l1: 0.189598	valid's auc: 0.959464
# [70]	valid's l1: 0.18895	valid's auc: 0.959758
# [71]	valid's l1: 0.188432	valid's auc: 0.960011
# [72]	valid's l1: 0.18781	valid's auc: 0.960244
# [73]	valid's l1: 0.187266	valid's auc: 0.960422
# [74]	valid's l1: 0.186749	valid's auc: 0.96058
# [75]	valid's l1: 0.185792	valid's auc: 0.960795
# [76]	valid's l1: 0.185196	valid's auc: 0.961034
# [77]	valid's l1: 0.18475	valid's auc: 0.961287
# [78]	valid's l1: 0.184284	valid's auc: 0.961392
# [79]	valid's l1: 0.183445	valid's auc: 0.961592
# [80]	valid's l1: 0.182878	valid's auc: 0.961952
# [81]	valid's l1: 0.182362	valid's auc: 0.962214
# [82]	valid's l1: 0.181948	valid's auc: 0.962601
# [83]	valid's l1: 0.181623	valid's auc: 0.962906
# [84]	valid's l1: 0.180959	valid's auc: 0.963334
# [85]	valid's l1: 0.180657	valid's auc: 0.963624
# [86]	valid's l1: 0.180154	valid's auc: 0.963977
# [87]	valid's l1: 0.179365	valid's auc: 0.964232
# [88]	valid's l1: 0.17896	valid's auc: 0.964362
# [89]	valid's l1: 0.178478	valid's auc: 0.964579
# [90]	valid's l1: 0.178038	valid's auc: 0.964854
# [91]	valid's l1: 0.177693	valid's auc: 0.965043
# [92]	valid's l1: 0.177215	valid's auc: 0.965243
# [93]	valid's l1: 0.176703	valid's auc: 0.965479
# [94]	valid's l1: 0.176076	valid's auc: 0.965741
# [95]	valid's l1: 0.175672	valid's auc: 0.965954
# [96]	valid's l1: 0.175359	valid's auc: 0.96607
# [97]	valid's l1: 0.175151	valid's auc: 0.966316
# [98]	valid's l1: 0.174892	valid's auc: 0.966442
# [99]	valid's l1: 0.174509	valid's auc: 0.966636
# [100]	valid's l1: 0.174068	valid's auc: 0.966843
# Did not meet early stopping. Best iteration is:
# [100]	valid's l1: 0.174068	valid's auc: 0.966843
# CPU times: user 2.57 s, sys: 166 ms, total: 2.73 s
# Wall time: 42.4 s
# Best score reached: 0.8644376979988684 with params: {'bagging_fraction': 0.3470727273814318, 'boosting_type': 'goss', 'early_stopping_round': 34, 'feature_fraction': 0.5893093786036377, 'lambda_l1': 5, 'lambda_l2': 0, 'max_depth': 12, 'metric': 'l1', 'min_data_in_leaf': 35, 'min_sum_hessian_in_leaf': 1e-05, 'num_leaves': 74, 'objective': 'binary', 'subsample': 0.43879623580243576}

# %%
y_train_pred = rs_1.predict(X_train_scaled)
y_train_prob = rs_1.predict_proba(X_train_scaled)[:, 1]
print("Train Results:")
show_results(y_train, y_train_pred, y_train_prob)

y_test_pred = rs_1.predict(X_test_scaled)
y_test_prob = rs_1.predict_proba(X_test_scaled)[:, 1]
print("Test Results:")
show_results(y_test, y_test_pred, y_test_prob)
# Out:
# Train Results:
#               precision    recall  f1-score   support
#
#            0      0.893     0.932     0.912     12462
#            1      0.911     0.862     0.886     10059
#
#     accuracy                          0.901     22521
#    macro avg      0.902     0.897     0.899     22521
# weighted avg      0.901     0.901     0.901     22521
#
# [[11620   842]
#  [ 1391  8668]]
# Accuracy: 0.9008480973313796
# AUC_ROC: 0.9668434330851922
# f1 score: 0.8858909499718943
# False Postive Rate: 0.06756539881238967
#
# Test Results:
#               precision    recall  f1-score   support
#
#            0      0.875     0.906     0.890      6138
#            1      0.878     0.839     0.858      4955
#
#     accuracy                          0.876     11093
#    macro avg      0.877     0.873     0.874     11093
# weighted avg      0.876     0.876     0.876     11093
#
# [[5562  576]
#  [ 796 4159]]
# Accuracy: 0.8763183989903542
# AUC_ROC: 0.9472140104866905
# f1 score: 0.8584107327141384
# False Postive Rate: 0.093841642228739

# %% [markdown]
# ###training best model for Top 15 Features + TF-IDF

# %%
clf_2 = lgbm.LGBMClassifier(random_state=1, silent=True)
rs_2 = RandomizedSearchCV(estimator = clf_2, 
                        param_distributions = param_test, 
                        refit = True,
                        random_state = 1,
                        n_jobs = -1
                        )

# %%
fit_params={"early_stopping_rounds":30, 
            "eval_metric" : ['auc', 'l1', 'average_precision'], 
            "eval_set" : [(X_train_tfidf, y_train)],
            'eval_names': ['valid'],
            'categorical_feature': 'auto',
            }
# %time rs_2.fit(X_train_tfidf, y_train, **fit_params)
print('Best score reached: {} with params: {} '.format(rs_2.best_score_, rs_2.best_params_))
# Out:
# /usr/local/lib/python3.7/dist-packages/joblib/externals/loky/process_executor.py:691: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:123: UserWarning: Found `early_stopping_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [1]	valid's l1: 0.46907	valid's auc: 0.909908
# Training until validation scores don't improve for 34 rounds.
# [2]	valid's l1: 0.447259	valid's auc: 0.942038
# [3]	valid's l1: 0.427371	valid's auc: 0.947796
# [4]	valid's l1: 0.405712	valid's auc: 0.954968
# [5]	valid's l1: 0.385863	valid's auc: 0.961044
# [6]	valid's l1: 0.368825	valid's auc: 0.966309
# [7]	valid's l1: 0.352401	valid's auc: 0.968916
# [8]	valid's l1: 0.342214	valid's auc: 0.969711
# [9]	valid's l1: 0.329228	valid's auc: 0.970305
# [10]	valid's l1: 0.315424	valid's auc: 0.971877
# [11]	valid's l1: 0.304533	valid's auc: 0.972526
# [12]	valid's l1: 0.293076	valid's auc: 0.973198
# [13]	valid's l1: 0.283654	valid's auc: 0.973734
# [14]	valid's l1: 0.275495	valid's auc: 0.973807
# [15]	valid's l1: 0.268601	valid's auc: 0.974037
# [16]	valid's l1: 0.26114	valid's auc: 0.974501
# [17]	valid's l1: 0.25408	valid's auc: 0.974712
# [18]	valid's l1: 0.248719	valid's auc: 0.975247
# [19]	valid's l1: 0.241178	valid's auc: 0.976346
# [20]	valid's l1: 0.234857	valid's auc: 0.976864
# [21]	valid's l1: 0.228502	valid's auc: 0.977433
# [22]	valid's l1: 0.222258	valid's auc: 0.978162
# [23]	valid's l1: 0.217534	valid's auc: 0.978661
# [24]	valid's l1: 0.213019	valid's auc: 0.979005
# [25]	valid's l1: 0.209915	valid's auc: 0.979456
# [26]	valid's l1: 0.205734	valid's auc: 0.97982
# [27]	valid's l1: 0.201681	valid's auc: 0.980103
# [28]	valid's l1: 0.197623	valid's auc: 0.980553
# [29]	valid's l1: 0.194231	valid's auc: 0.980875
# [30]	valid's l1: 0.19137	valid's auc: 0.981153
# [31]	valid's l1: 0.188976	valid's auc: 0.981479
# [32]	valid's l1: 0.186614	valid's auc: 0.981789
# [33]	valid's l1: 0.182536	valid's auc: 0.982138
# [34]	valid's l1: 0.178821	valid's auc: 0.982444
# [35]	valid's l1: 0.176352	valid's auc: 0.982903
# [36]	valid's l1: 0.173774	valid's auc: 0.983102
# [37]	valid's l1: 0.171277	valid's auc: 0.983393
# [38]	valid's l1: 0.168929	valid's auc: 0.983548
# [39]	valid's l1: 0.167295	valid's auc: 0.983838
# [40]	valid's l1: 0.165792	valid's auc: 0.984104
# [41]	valid's l1: 0.164255	valid's auc: 0.984383
# [42]	valid's l1: 0.162444	valid's auc: 0.984624
# [43]	valid's l1: 0.160814	valid's auc: 0.984838
# [44]	valid's l1: 0.159469	valid's auc: 0.985047
# [45]	valid's l1: 0.157354	valid's auc: 0.985209
# [46]	valid's l1: 0.155642	valid's auc: 0.985436
# [47]	valid's l1: 0.153872	valid's auc: 0.985619
# [48]	valid's l1: 0.152359	valid's auc: 0.985803
# [49]	valid's l1: 0.150777	valid's auc: 0.98591
# [50]	valid's l1: 0.14952	valid's auc: 0.98615
# [51]	valid's l1: 0.148408	valid's auc: 0.986354
# [52]	valid's l1: 0.147187	valid's auc: 0.986517
# [53]	valid's l1: 0.146193	valid's auc: 0.986724
# [54]	valid's l1: 0.144651	valid's auc: 0.986889
# [55]	valid's l1: 0.143594	valid's auc: 0.987071
# [56]	valid's l1: 0.14252	valid's auc: 0.987226
# [57]	valid's l1: 0.141608	valid's auc: 0.987383
# [58]	valid's l1: 0.140584	valid's auc: 0.987487
# [59]	valid's l1: 0.138778	valid's auc: 0.987688
# [60]	valid's l1: 0.137436	valid's auc: 0.987835
# [61]	valid's l1: 0.135727	valid's auc: 0.988055
# [62]	valid's l1: 0.13417	valid's auc: 0.98815
# [63]	valid's l1: 0.133368	valid's auc: 0.988314
# [64]	valid's l1: 0.132529	valid's auc: 0.98845
# [65]	valid's l1: 0.131744	valid's auc: 0.988606
# [66]	valid's l1: 0.130631	valid's auc: 0.98873
# [67]	valid's l1: 0.129925	valid's auc: 0.988864
# [68]	valid's l1: 0.128525	valid's auc: 0.989085
# [69]	valid's l1: 0.127556	valid's auc: 0.98922
# [70]	valid's l1: 0.126957	valid's auc: 0.989372
# [71]	valid's l1: 0.126269	valid's auc: 0.989478
# [72]	valid's l1: 0.125669	valid's auc: 0.989587
# [73]	valid's l1: 0.124925	valid's auc: 0.989727
# [74]	valid's l1: 0.12425	valid's auc: 0.989822
# [75]	valid's l1: 0.123391	valid's auc: 0.989887
# [76]	valid's l1: 0.122188	valid's auc: 0.990056
# [77]	valid's l1: 0.121294	valid's auc: 0.990144
# [78]	valid's l1: 0.120659	valid's auc: 0.990271
# [79]	valid's l1: 0.120085	valid's auc: 0.990371
# [80]	valid's l1: 0.119457	valid's auc: 0.990465
# [81]	valid's l1: 0.118598	valid's auc: 0.990558
# [82]	valid's l1: 0.11776	valid's auc: 0.990658
# [83]	valid's l1: 0.117167	valid's auc: 0.990753
# [84]	valid's l1: 0.116256	valid's auc: 0.990816
# [85]	valid's l1: 0.115647	valid's auc: 0.990892
# [86]	valid's l1: 0.11463	valid's auc: 0.990977
# [87]	valid's l1: 0.113673	valid's auc: 0.991065
# [88]	valid's l1: 0.112877	valid's auc: 0.991154
# [89]	valid's l1: 0.112323	valid's auc: 0.991215
# [90]	valid's l1: 0.11185	valid's auc: 0.991297
# [91]	valid's l1: 0.111267	valid's auc: 0.991357
# [92]	valid's l1: 0.110735	valid's auc: 0.991413
# [93]	valid's l1: 0.109883	valid's auc: 0.991481
# [94]	valid's l1: 0.109402	valid's auc: 0.991544
# [95]	valid's l1: 0.108973	valid's auc: 0.991606
# [96]	valid's l1: 0.108552	valid's auc: 0.991692
# [97]	valid's l1: 0.108215	valid's auc: 0.991811
# [98]	valid's l1: 0.107843	valid's auc: 0.991897
# [99]	valid's l1: 0.107428	valid's auc: 0.991981
# [100]	valid's l1: 0.106982	valid's auc: 0.992032
# Did not meet early stopping. Best iteration is:
# [100]	valid's l1: 0.106982	valid's auc: 0.992032
# CPU times: user 12.9 s, sys: 608 ms, total: 13.5 s
# Wall time: 4min 5s
# Best score reached: 0.9434305774322196 with params: {'bagging_fraction': 0.3470727273814318, 'boosting_type': 'goss', 'early_stopping_round': 34, 'feature_fraction': 0.5893093786036377, 'lambda_l1': 5, 'lambda_l2': 0, 'max_depth': 12, 'metric': 'l1', 'min_data_in_leaf': 35, 'min_sum_hessian_in_leaf': 1e-05, 'num_leaves': 74, 'objective': 'binary', 'subsample': 0.43879623580243576}

# %%
y_train_pred = rs_2.predict(X_train_tfidf)
y_train_prob = rs_2.predict_proba(X_train_tfidf)[:, 1]
print("Train Results:")
show_results(y_train, y_train_pred, y_train_prob)

y_test_pred = rs_2.predict(X_test_tfidf)
y_test_prob = rs_2.predict_proba(X_test_tfidf)[:, 1]
print("Test Results:")
show_results(y_test, y_test_pred, y_test_prob)
# Out:
# Train Results:
#               precision    recall  f1-score   support
#
#            0      0.957     0.970     0.963     12462
#            1      0.962     0.946     0.954     10059
#
#     accuracy                          0.959     22521
#    macro avg      0.959     0.958     0.958     22521
# weighted avg      0.959     0.959     0.959     22521
#
# [[12083   379]
#  [  546  9513]]
# Accuracy: 0.9589272234803072
# AUC_ROC: 0.9920320773461293
# f1 score: 0.9536364092025463
# False Postive Rate: 0.03041245385973359
#
# Test Results:
#               precision    recall  f1-score   support
#
#            0      0.946     0.960     0.953      6138
#            1      0.949     0.932     0.941      4955
#
#     accuracy                          0.947     11093
#    macro avg      0.948     0.946     0.947     11093
# weighted avg      0.947     0.947     0.947     11093
#
# [[5890  248]
#  [ 335 4620]]
# Accuracy: 0.9474443342648518
# AUC_ROC: 0.9886267380684881
# f1 score: 0.9406494960806271
# False Postive Rate: 0.04040404040404041

# %% [markdown]
# ###training best model for Top 15 Features + TF-IDF weighted GloVe vectors

# %%
clf_3 = lgbm.LGBMClassifier(random_state=1, silent=True)
rs_3 = RandomizedSearchCV(estimator = clf_3, 
                        param_distributions = param_test, 
                        refit = True,
                        random_state = 1,
                        n_jobs = -1
                        )

# %%
fit_params={"early_stopping_rounds":30, 
            "eval_metric" : ['auc', 'l1', 'average_precision'], 
            "eval_set" : [(X_train_tfidf_glove, y_train)],
            'eval_names': ['valid'],
            'categorical_feature': 'auto',
            }
# %time rs_3.fit(X_train_tfidf_glove, y_train, **fit_params)
print('Best score reached: {} with params: {} '.format(rs_3.best_score_, rs_3.best_params_))
# Out:
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:123: UserWarning: Found `early_stopping_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [1]	valid's l1: 0.466298	valid's auc: 0.922959
# Training until validation scores don't improve for 34 rounds.
# [2]	valid's l1: 0.444775	valid's auc: 0.949514
# [3]	valid's l1: 0.422044	valid's auc: 0.961373
# [4]	valid's l1: 0.402508	valid's auc: 0.968439
# [5]	valid's l1: 0.382746	valid's auc: 0.971453
# [6]	valid's l1: 0.363559	valid's auc: 0.974338
# [7]	valid's l1: 0.347591	valid's auc: 0.976327
# [8]	valid's l1: 0.331039	valid's auc: 0.978342
# [9]	valid's l1: 0.316494	valid's auc: 0.97906
# [10]	valid's l1: 0.302493	valid's auc: 0.980886
# [11]	valid's l1: 0.291114	valid's auc: 0.981527
# [12]	valid's l1: 0.279733	valid's auc: 0.982644
# [13]	valid's l1: 0.268268	valid's auc: 0.983541
# [14]	valid's l1: 0.258443	valid's auc: 0.984396
# [15]	valid's l1: 0.249253	valid's auc: 0.985124
# [16]	valid's l1: 0.24026	valid's auc: 0.985815
# [17]	valid's l1: 0.233145	valid's auc: 0.986379
# [18]	valid's l1: 0.224779	valid's auc: 0.987022
# [19]	valid's l1: 0.217305	valid's auc: 0.987651
# [20]	valid's l1: 0.210428	valid's auc: 0.988149
# [21]	valid's l1: 0.204568	valid's auc: 0.988377
# [22]	valid's l1: 0.198361	valid's auc: 0.988793
# [23]	valid's l1: 0.193885	valid's auc: 0.989322
# [24]	valid's l1: 0.188774	valid's auc: 0.989745
# [25]	valid's l1: 0.184369	valid's auc: 0.9903
# [26]	valid's l1: 0.179597	valid's auc: 0.990643
# [27]	valid's l1: 0.174593	valid's auc: 0.991109
# [28]	valid's l1: 0.170463	valid's auc: 0.991494
# [29]	valid's l1: 0.165988	valid's auc: 0.991899
# [30]	valid's l1: 0.160817	valid's auc: 0.992289
# [31]	valid's l1: 0.157334	valid's auc: 0.992651
# [32]	valid's l1: 0.154109	valid's auc: 0.993012
# [33]	valid's l1: 0.150153	valid's auc: 0.993319
# [34]	valid's l1: 0.147197	valid's auc: 0.993613
# [35]	valid's l1: 0.144403	valid's auc: 0.993872
# [36]	valid's l1: 0.141104	valid's auc: 0.99409
# [37]	valid's l1: 0.138342	valid's auc: 0.99434
# [38]	valid's l1: 0.135724	valid's auc: 0.994549
# [39]	valid's l1: 0.132705	valid's auc: 0.994742
# [40]	valid's l1: 0.130196	valid's auc: 0.994945
# [41]	valid's l1: 0.127431	valid's auc: 0.995165
# [42]	valid's l1: 0.124507	valid's auc: 0.995359
# [43]	valid's l1: 0.122428	valid's auc: 0.995583
# [44]	valid's l1: 0.120347	valid's auc: 0.995762
# [45]	valid's l1: 0.118321	valid's auc: 0.995951
# [46]	valid's l1: 0.115913	valid's auc: 0.996129
# [47]	valid's l1: 0.113261	valid's auc: 0.996289
# [48]	valid's l1: 0.111525	valid's auc: 0.996468
# [49]	valid's l1: 0.109834	valid's auc: 0.996626
# [50]	valid's l1: 0.108205	valid's auc: 0.996784
# [51]	valid's l1: 0.10657	valid's auc: 0.996939
# [52]	valid's l1: 0.105002	valid's auc: 0.99709
# [53]	valid's l1: 0.103396	valid's auc: 0.997229
# [54]	valid's l1: 0.101984	valid's auc: 0.997353
# [55]	valid's l1: 0.100365	valid's auc: 0.997491
# [56]	valid's l1: 0.0982984	valid's auc: 0.997588
# [57]	valid's l1: 0.0968814	valid's auc: 0.99771
# [58]	valid's l1: 0.0955326	valid's auc: 0.997809
# [59]	valid's l1: 0.0942171	valid's auc: 0.997941
# [60]	valid's l1: 0.0925509	valid's auc: 0.998018
# [61]	valid's l1: 0.0913293	valid's auc: 0.998123
# [62]	valid's l1: 0.0901301	valid's auc: 0.998215
# [63]	valid's l1: 0.0885902	valid's auc: 0.9983
# [64]	valid's l1: 0.0872464	valid's auc: 0.998394
# [65]	valid's l1: 0.0855503	valid's auc: 0.998446
# [66]	valid's l1: 0.0843338	valid's auc: 0.998536
# [67]	valid's l1: 0.0833222	valid's auc: 0.9986
# [68]	valid's l1: 0.0822533	valid's auc: 0.998667
# [69]	valid's l1: 0.0809252	valid's auc: 0.998717
# [70]	valid's l1: 0.0795052	valid's auc: 0.998776
# [71]	valid's l1: 0.0786362	valid's auc: 0.998831
# [72]	valid's l1: 0.0776712	valid's auc: 0.998904
# [73]	valid's l1: 0.0766512	valid's auc: 0.998955
# [74]	valid's l1: 0.0757041	valid's auc: 0.999007
# [75]	valid's l1: 0.0747446	valid's auc: 0.999053
# [76]	valid's l1: 0.0734701	valid's auc: 0.999086
# [77]	valid's l1: 0.0725987	valid's auc: 0.999137
# [78]	valid's l1: 0.0717051	valid's auc: 0.999183
# [79]	valid's l1: 0.0708662	valid's auc: 0.999227
# [80]	valid's l1: 0.069932	valid's auc: 0.999271
# [81]	valid's l1: 0.068978	valid's auc: 0.999302
# [82]	valid's l1: 0.0681635	valid's auc: 0.999344
# [83]	valid's l1: 0.0673175	valid's auc: 0.999368
# [84]	valid's l1: 0.0665905	valid's auc: 0.999405
# [85]	valid's l1: 0.0658469	valid's auc: 0.999436
# [86]	valid's l1: 0.0651709	valid's auc: 0.99947
# [87]	valid's l1: 0.0644748	valid's auc: 0.999499
# [88]	valid's l1: 0.06372	valid's auc: 0.99953
# [89]	valid's l1: 0.0629641	valid's auc: 0.999551
# [90]	valid's l1: 0.062215	valid's auc: 0.999563
# [91]	valid's l1: 0.0615173	valid's auc: 0.999584
# [92]	valid's l1: 0.0608621	valid's auc: 0.999605
# [93]	valid's l1: 0.0601863	valid's auc: 0.999628
# [94]	valid's l1: 0.0595584	valid's auc: 0.999648
# [95]	valid's l1: 0.0588524	valid's auc: 0.999663
# [96]	valid's l1: 0.0582634	valid's auc: 0.999679
# [97]	valid's l1: 0.057628	valid's auc: 0.999695
# [98]	valid's l1: 0.0570409	valid's auc: 0.999713
# [99]	valid's l1: 0.0562364	valid's auc: 0.99972
# [100]	valid's l1: 0.0553906	valid's auc: 0.999734
# Did not meet early stopping. Best iteration is:
# [100]	valid's l1: 0.0553906	valid's auc: 0.999734
# CPU times: user 16.5 s, sys: 391 ms, total: 16.9 s
# Wall time: 4min 15s
# Best score reached: 0.9450736501578078 with params: {'bagging_fraction': 0.3470727273814318, 'boosting_type': 'goss', 'early_stopping_round': 34, 'feature_fraction': 0.5893093786036377, 'lambda_l1': 5, 'lambda_l2': 0, 'max_depth': 12, 'metric': 'l1', 'min_data_in_leaf': 35, 'min_sum_hessian_in_leaf': 1e-05, 'num_leaves': 74, 'objective': 'binary', 'subsample': 0.43879623580243576}

# %%
y_train_pred = rs_3.predict(X_train_tfidf_glove)
y_train_prob = rs_3.predict_proba(X_train_tfidf_glove)[:, 1]
print("Train Results:")
show_results(y_train, y_train_pred, y_train_prob)

y_test_pred = rs_3.predict(X_test_tfidf_glove)
y_test_prob = rs_3.predict_proba(X_test_tfidf_glove)[:, 1]
print("Test Results:")
show_results(y_test, y_test_pred, y_test_prob)
# Out:
# Train Results:
#               precision    recall  f1-score   support
#
#            0      0.993     0.997     0.995     12462
#            1      0.996     0.991     0.994     10059
#
#     accuracy                          0.994     22521
#    macro avg      0.995     0.994     0.994     22521
# weighted avg      0.994     0.994     0.994     22521
#
# [[12424    38]
#  [   88  9971]]
# Accuracy: 0.9944052217929932
# AUC_ROC: 0.9997342512748848
# f1 score: 0.993721347418776
# False Postive Rate: 0.0030492697801316002
#
# Test Results:
#               precision    recall  f1-score   support
#
#            0      0.953     0.958     0.955      6138
#            1      0.947     0.941     0.944      4955
#
#     accuracy                          0.950     11093
#    macro avg      0.950     0.949     0.950     11093
# weighted avg      0.950     0.950     0.950     11093
#
# [[5879  259]
#  [ 292 4663]]
# Accuracy: 0.9503290363292166
# AUC_ROC: 0.9902216395917773
# f1 score: 0.9442138301103573
# False Postive Rate: 0.042196155099380905

# %% [markdown]
# ###training best model for Top 15 Features + TF-IDF weighted FastText

# %%
clf_4 = lgbm.LGBMClassifier(random_state=1, silent=True)
rs_4 = RandomizedSearchCV(estimator = clf_4, 
                        param_distributions = param_test, 
                        refit = True,
                        random_state = 1,
                        n_jobs = -1
                        )

# %%
fit_params={"early_stopping_rounds":30, 
            "eval_metric" : ['auc', 'l1', 'average_precision'], 
            "eval_set" : [(X_train_tfidf_cc, y_train)],
            'eval_names': ['valid'],
            'categorical_feature': 'auto',
            }
# %time rs_4.fit(X_train_tfidf_cc, y_train, **fit_params)
print('Best score reached: {} with params: {} '.format(rs_4.best_score_, rs_4.best_params_))
# Out:
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:123: UserWarning: Found `early_stopping_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [1]	valid's l1: 0.46636	valid's auc: 0.922108
# Training until validation scores don't improve for 34 rounds.
# [2]	valid's l1: 0.443972	valid's auc: 0.954029
# [3]	valid's l1: 0.419795	valid's auc: 0.968742
# [4]	valid's l1: 0.400122	valid's auc: 0.972706
# [5]	valid's l1: 0.381059	valid's auc: 0.975488
# [6]	valid's l1: 0.361832	valid's auc: 0.978712
# [7]	valid's l1: 0.345643	valid's auc: 0.979493
# [8]	valid's l1: 0.328837	valid's auc: 0.982295
# [9]	valid's l1: 0.314118	valid's auc: 0.983049
# [10]	valid's l1: 0.300214	valid's auc: 0.98389
# [11]	valid's l1: 0.289555	valid's auc: 0.984494
# [12]	valid's l1: 0.278177	valid's auc: 0.985435
# [13]	valid's l1: 0.267509	valid's auc: 0.98642
# [14]	valid's l1: 0.25764	valid's auc: 0.987047
# [15]	valid's l1: 0.248393	valid's auc: 0.987869
# [16]	valid's l1: 0.238743	valid's auc: 0.988642
# [17]	valid's l1: 0.231343	valid's auc: 0.989382
# [18]	valid's l1: 0.222772	valid's auc: 0.989912
# [19]	valid's l1: 0.21538	valid's auc: 0.990336
# [20]	valid's l1: 0.208013	valid's auc: 0.990935
# [21]	valid's l1: 0.200404	valid's auc: 0.991431
# [22]	valid's l1: 0.193995	valid's auc: 0.991777
# [23]	valid's l1: 0.189019	valid's auc: 0.992193
# [24]	valid's l1: 0.183828	valid's auc: 0.992508
# [25]	valid's l1: 0.178583	valid's auc: 0.992877
# [26]	valid's l1: 0.173285	valid's auc: 0.993171
# [27]	valid's l1: 0.167997	valid's auc: 0.993518
# [28]	valid's l1: 0.163855	valid's auc: 0.993791
# [29]	valid's l1: 0.159854	valid's auc: 0.994046
# [30]	valid's l1: 0.155546	valid's auc: 0.994296
# [31]	valid's l1: 0.151639	valid's auc: 0.994632
# [32]	valid's l1: 0.147597	valid's auc: 0.994932
# [33]	valid's l1: 0.144046	valid's auc: 0.99518
# [34]	valid's l1: 0.140786	valid's auc: 0.99544
# [35]	valid's l1: 0.137176	valid's auc: 0.995682
# [36]	valid's l1: 0.134465	valid's auc: 0.995874
# [37]	valid's l1: 0.131949	valid's auc: 0.996074
# [38]	valid's l1: 0.129086	valid's auc: 0.996245
# [39]	valid's l1: 0.126186	valid's auc: 0.996446
# [40]	valid's l1: 0.123668	valid's auc: 0.996596
# [41]	valid's l1: 0.121323	valid's auc: 0.99676
# [42]	valid's l1: 0.118975	valid's auc: 0.996938
# [43]	valid's l1: 0.116788	valid's auc: 0.997093
# [44]	valid's l1: 0.114608	valid's auc: 0.997236
# [45]	valid's l1: 0.112014	valid's auc: 0.997353
# [46]	valid's l1: 0.109117	valid's auc: 0.997468
# [47]	valid's l1: 0.106399	valid's auc: 0.997572
# [48]	valid's l1: 0.104461	valid's auc: 0.997699
# [49]	valid's l1: 0.102601	valid's auc: 0.99781
# [50]	valid's l1: 0.10096	valid's auc: 0.997931
# [51]	valid's l1: 0.0991133	valid's auc: 0.998028
# [52]	valid's l1: 0.0976779	valid's auc: 0.998131
# [53]	valid's l1: 0.0959878	valid's auc: 0.998224
# [54]	valid's l1: 0.0944566	valid's auc: 0.998319
# [55]	valid's l1: 0.0929631	valid's auc: 0.998392
# [56]	valid's l1: 0.0910238	valid's auc: 0.998451
# [57]	valid's l1: 0.0894184	valid's auc: 0.998517
# [58]	valid's l1: 0.0879067	valid's auc: 0.998601
# [59]	valid's l1: 0.0865185	valid's auc: 0.998667
# [60]	valid's l1: 0.0851549	valid's auc: 0.99874
# [61]	valid's l1: 0.0840029	valid's auc: 0.998808
# [62]	valid's l1: 0.0827325	valid's auc: 0.998861
# [63]	valid's l1: 0.0808949	valid's auc: 0.998923
# [64]	valid's l1: 0.0796335	valid's auc: 0.998977
# [65]	valid's l1: 0.0782599	valid's auc: 0.999021
# [66]	valid's l1: 0.0771747	valid's auc: 0.999069
# [67]	valid's l1: 0.0761376	valid's auc: 0.999118
# [68]	valid's l1: 0.0750666	valid's auc: 0.999176
# [69]	valid's l1: 0.0739182	valid's auc: 0.999223
# [70]	valid's l1: 0.0727044	valid's auc: 0.999263
# [71]	valid's l1: 0.0717912	valid's auc: 0.999301
# [72]	valid's l1: 0.0709063	valid's auc: 0.999331
# [73]	valid's l1: 0.070021	valid's auc: 0.999372
# [74]	valid's l1: 0.0691318	valid's auc: 0.999414
# [75]	valid's l1: 0.068157	valid's auc: 0.999449
# [76]	valid's l1: 0.0671731	valid's auc: 0.999476
# [77]	valid's l1: 0.0663111	valid's auc: 0.999497
# [78]	valid's l1: 0.0651107	valid's auc: 0.999524
# [79]	valid's l1: 0.0640695	valid's auc: 0.999551
# [80]	valid's l1: 0.0630357	valid's auc: 0.999575
# [81]	valid's l1: 0.0621904	valid's auc: 0.999598
# [82]	valid's l1: 0.0613885	valid's auc: 0.99962
# [83]	valid's l1: 0.0604591	valid's auc: 0.999636
# [84]	valid's l1: 0.0597412	valid's auc: 0.999658
# [85]	valid's l1: 0.0589027	valid's auc: 0.999678
# [86]	valid's l1: 0.0582003	valid's auc: 0.999698
# [87]	valid's l1: 0.0572989	valid's auc: 0.999712
# [88]	valid's l1: 0.0565613	valid's auc: 0.999725
# [89]	valid's l1: 0.0559438	valid's auc: 0.999744
# [90]	valid's l1: 0.0552269	valid's auc: 0.999761
# [91]	valid's l1: 0.0546587	valid's auc: 0.99978
# [92]	valid's l1: 0.0539721	valid's auc: 0.999789
# [93]	valid's l1: 0.0532588	valid's auc: 0.999802
# [94]	valid's l1: 0.0526619	valid's auc: 0.999815
# [95]	valid's l1: 0.0520363	valid's auc: 0.999827
# [96]	valid's l1: 0.0514337	valid's auc: 0.999838
# [97]	valid's l1: 0.0508772	valid's auc: 0.999848
# [98]	valid's l1: 0.0503037	valid's auc: 0.999856
# [99]	valid's l1: 0.0497377	valid's auc: 0.999866
# [100]	valid's l1: 0.0491586	valid's auc: 0.99987
# Did not meet early stopping. Best iteration is:
# [100]	valid's l1: 0.0491586	valid's auc: 0.99987
# CPU times: user 16.2 s, sys: 333 ms, total: 16.5 s
# Wall time: 4min 13s
# Best score reached: 0.9548866268582572 with params: {'bagging_fraction': 0.3470727273814318, 'boosting_type': 'goss', 'early_stopping_round': 34, 'feature_fraction': 0.5893093786036377, 'lambda_l1': 5, 'lambda_l2': 0, 'max_depth': 12, 'metric': 'l1', 'min_data_in_leaf': 35, 'min_sum_hessian_in_leaf': 1e-05, 'num_leaves': 74, 'objective': 'binary', 'subsample': 0.43879623580243576}

# %%
y_train_pred = rs_4.predict(X_train_tfidf_cc)
y_train_prob = rs_4.predict_proba(X_train_tfidf_cc)[:, 1]
print("Train Results:")
show_results(y_train, y_train_pred, y_train_prob)

y_test_pred = rs_4.predict(X_test_tfidf_cc)
y_test_prob = rs_4.predict_proba(X_test_tfidf_cc)[:, 1]
print("Test Results:")
show_results(y_test, y_test_pred, y_test_prob)
# Out:
# Train Results:
#               precision    recall  f1-score   support
#
#            0      0.995     0.998     0.997     12462
#            1      0.997     0.994     0.996     10059
#
#     accuracy                          0.996     22521
#    macro avg      0.996     0.996     0.996     22521
# weighted avg      0.996     0.996     0.996     22521
#
# [[12436    26]
#  [   59 10000]]
# Accuracy: 0.9962257448603525
# AUC_ROC: 0.9998700413507984
# f1 score: 0.9957679860592481
# False Postive Rate: 0.0020863424811426736
#
# Test Results:
#               precision    recall  f1-score   support
#
#            0      0.958     0.970     0.964      6138
#            1      0.963     0.947     0.955      4955
#
#     accuracy                          0.960     11093
#    macro avg      0.960     0.959     0.959     11093
# weighted avg      0.960     0.960     0.960     11093
#
# [[5956  182]
#  [ 264 4691]]
# Accuracy: 0.959794464977914
# AUC_ROC: 0.9929039261466591
# f1 score: 0.9546194546194546
# False Postive Rate: 0.029651352231997392

# %% [markdown]
# ### InferSent

# %%
clf = lgbm.LGBMClassifier(random_state=1)
# rs = RandomizedSearchCV(estimator = clf, 
#                         param_distributions = param_test, 
#                         refit = True,
#                         random_state = 1,
#                         n_jobs = -1
#                         )

# fit_params={"early_stopping_rounds":30, 
#             "eval_metric" : ['auc', 'l1', 'average_precision'], 
#             "eval_set" : [(X_train_scaled, y_train)],
#             'eval_names': ['valid'],
#             'categorical_feature': 'auto',
#             }
# %time clf.fit(X_train_infersent, y_train_infersent)
# print('Best score reached: {} with params: {} '.format(rs.best_score_, rs.best_params_))
# Out:
# CPU times: user 4min 37s, sys: 2.03 s, total: 4min 39s
# Wall time: 2min 25s
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=1, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
y_train_pred = clf.predict(X_train_infersent)
y_train_prob = clf.predict_proba(X_train_infersent)[:, 1]
print("Train Results:")
show_results(y_train_infersent, y_train_pred, y_train_prob)

y_test_pred = clf.predict(X_test_infersent)
y_test_prob = clf.predict_proba(X_test_infersent)[:, 1]
print("Test Results:")
show_results(y_test_infersent, y_test_pred, y_test_prob)
# Out:
# Train Results:
#               precision    recall  f1-score   support
#
#            0      0.952     0.979     0.966     10560
#            1      0.968     0.926     0.946      6979
#
#     accuracy                          0.958     17539
#    macro avg      0.960     0.953     0.956     17539
# weighted avg      0.958     0.958     0.958     17539
#
# [[10343   217]
#  [  519  6460]]
# Accuracy: 0.9580363760761731
# AUC_ROC: 0.9939218358538819
# f1 score: 0.9461042765084944
# False Postive Rate: 0.020549242424242425
#
# Test Results:
#               precision    recall  f1-score   support
#
#            0      0.874     0.914     0.893      5191
#            1      0.860     0.800     0.829      3422
#
#     accuracy                          0.869      8613
#    macro avg      0.867     0.857     0.861      8613
# weighted avg      0.868     0.869     0.868      8613
#
# [[4745  446]
#  [ 686 2736]]
# Accuracy: 0.8685707651224892
# AUC_ROC: 0.9399785021078495
# f1 score: 0.8285887341005451
# False Postive Rate: 0.08591793488730495
